# %%
import sys; sys.path.append('../')
 
from vision import NNTextDetect
import matplotlib.pyplot as plt
import cv2

# %%
det = NNTextDetect('../weights/east_text_detection_weights.pb')
img = cv2.imread('../test-data/test_killfeed.png')
bboxes = det.detect_text(img)
resized_img = det._resize_closest_multiple(img)  # what the prediction was ran on 
plt.imshow(det.draw_bboxes(img,bboxes))

# %%
resized_img = det._resize_closest_multiple(img, 32)
scores, geom = det._predict(resized_img)
scores.shape, geom.shape
# Out:
# ((1, 1, 32, 96), (1, 5, 32, 96))

# %%
y_centers = [(startY+endY)/2 for (startX, startY, endX, endY) in bboxes]
y_centers
# Out:
# [46.5,
#  15.5,
#  46.5,
#  46.5,
#  15.5,
#  16.0,
#  107.0,
#  15.0,
#  15.0,
#  76.5,
#  74.5,
#  77.0,
#  77.5,
#  106.5,
#  76.5,
#  107.0]

# %%
scores.shape
# Out:
# (1, 1, 80, 80)

# %%
numRows,numCols
# Out:
# (80, 80)
